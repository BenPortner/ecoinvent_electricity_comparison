# %% [markdown]
# # What is the most sustainable way to generate electricity? A comparison of ecoinvent datasets.

# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Introduction" data-toc-modified-id="Introduction-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Introduction</a></span></li><li><span><a href="#Calculation" data-toc-modified-id="Calculation-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Calculation</a></span><ul class="toc-item"><li><span><a href="#ILCD-scores" data-toc-modified-id="ILCD-scores-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>ILCD scores</a></span></li><li><span><a href="#Sustainability-Index" data-toc-modified-id="Sustainability-Index-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Sustainability Index</a></span><ul class="toc-item"><li><span><a href="#Normalization" data-toc-modified-id="Normalization-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Normalization</a></span></li><li><span><a href="#Weighing-and-aggregation" data-toc-modified-id="Weighing-and-aggregation-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Weighing and aggregation</a></span></li></ul></li><li><span><a href="#Export" data-toc-modified-id="Export-2.3"><span class="toc-item-num">2.3&nbsp;&nbsp;</span>Export</a></span></li><li><span><a href="#Visualization" data-toc-modified-id="Visualization-2.4"><span class="toc-item-num">2.4&nbsp;&nbsp;</span>Visualization</a></span></li></ul></li><li><span><a href="#Discussion" data-toc-modified-id="Discussion-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Discussion</a></span></li></ul></div>

# %% [markdown]
# ## Introduction
#
# Which electricity generation technology is the most sustainable one? Is it photovoltaic panels on house roofs? Is it off-shore wind parks? Is it nuclear pressure water reactors?! The answer will depend on several aspects.
#
# First of all, it depends on the models used to describe the different generation technologies. Here, I will use models and parameters as supplied by ecoinvent 3.5, allocation at the point of substitution system model (https://www.ecoinvent.org/).
#
# Secondly, it will depend on how we define sustainability. For example, wind energy seems very sustainable from a climate change point of view (low green house gas emissions). However, wind turbines need large amounts of minerals and metals in their construction, making them seem less sustainable from a resource point of view. This is one example of how different indicators will yield different answers. For this study, I will use the 19 midpoint indicators recommended by the International Reference Life Cycle Data System, version 2.0, as implemented in ecoinvent 3.5. I will present results for each indicator. Additionally, I will present normalized, equal-weighted aggregates. The later is just *one* example of how to aggregate multiple indicators to yield one sustainability index. There are infinitely many ways to aggregate different indicators and none of them is preferable over the other. In the end, sustainability measures will always be a subjective construct because different stakeholders give different emphasis to different impact categories.

# %% [markdown]
# ## Calculation
#
# ### ILCD scores
# I use the brightway2 package for python for impact calculations (https://brightwaylca.org/). Brightway allows to
# - read the database (ecoinvent 3.5 APOS)
# - query the database for activities (all electricity production activities in the database)
# - calculate the impact score of activities according to different methods (ILCD 2.0)
#
# First, imports.

# %%
import brightway2 as bw
import pandas as pd
import xlsxwriter

# %% [markdown]
# I'll skip the setup here. Please refer to the official brightway guide for details on how to import the ecoinvent 3.5 database etc.: https://nbviewer.jupyter.org/urls/bitbucket.org/cmutel/brightway2/raw/default/notebooks/Getting%20Started%20with%20Brightway2.ipynb
#
# Let's start by getting all electricity production activities in the database.

# %%
# setting the directory containing ecoinvent 3.5 APOS database
bw.projects.set_current("ecoinvent-import")

# querying 
lActivities = [a for a in bw.Database("ecoinvent 3.5 APOS") if "electricity production" in a["name"]]

len(lActivities)
# Out:
# 1488

# %% [markdown]
# ecoinvent knows 1,488 different activities that produce electricity! Let's go ahead and calculate their impacts.
#
# **Note: Computation of all values may take up to an hour! I reduced the number of activities to the first 5 in the list to make the notebook runable. Feel free to delete the corresponding line to calculate all impacts on your system.**

# %%
###### delete line below to calculate ALL impacts ######
lActivities = lActivities[:5]
########################################################

# get ILCD 2.0 midpoint methods
ilcd = [m for m in bw.methods if "ILCD" in str(m) and "2018" in str(m) and "LT" not in str(m)]

# compute all ILCD scores for all activities
ldScores = []
for a in lActivities:
    oLCA = bw.LCA({a:1}, ilcd[0])
    oLCA.lci()
    oLCA.lcia()
    dScores = {ilcd[0]:oLCA.score}
    for oMethod in ilcd[1:]:
        oLCA.switch_method(oMethod)
        oLCA.lcia()
        dScores[oMethod] = oLCA.score
    ldScores.append(dScores)
    
# convert to dataframe
df = pd.DataFrame(ldScores)
df.head()
# Out:
#    (ILCD 2.0 2018 midpoint, climate change, climate change biogenic)  \
# 0                                           0.000053
# 1                                           0.000162
# 2                                           0.000026
# 3                                           0.000363
# 4                                           0.000287
#
#    (ILCD 2.0 2018 midpoint, climate change, climate change fossil)  \
# 0                                           0.588143
# 1                                           1.053454
# 2                                           0.012671
# 3                                           0.077957
# 4                                           0.061599
#
#    (ILCD 2.0 2018 midpoint, climate change, climate change land use and land use change)  \
# 0                                           0.000015
# 1                                           0.000078
# 2                                           0.000030
# 3                                           0.000177
# 4                                           0.000140
#
#    (ILCD 2.0 2018 midpoint, climate change, climate change total)  \
# 0                                           0.588211
# 1                                           1.053694
# 2                                           0.012726
# 3                                           0.078496
# 4                                           0.062025
#
#    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater and terrestrial acidification)  \
# 0                                           0.000645
# 1                                           0.010851
# 2                                           0.000074
# 3                                           0.000570
# 4                                           0.000450
#
#    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater ecotoxicity)  \
# 0                                           0.217072
# 1                                           0.074229
# 2                                           0.025228
# 3                                           0.089036
# 4                                           0.070353
#
#    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater eutrophication)  \
# 0                                           0.000008
# 1                                           0.000753
# 2                                           0.000009
# 3                                           0.000072
# 4                                           0.000057
#
#    (ILCD 2.0 2018 midpoint, ecosystem quality, marine eutrophication)  \
# 0                                           0.000180
# 1                                           0.001528
# 2                                           0.000060
# 3                                           0.000101
# 4                                           0.000080
#
#    (ILCD 2.0 2018 midpoint, ecosystem quality, terrestrial eutrophication)  \
# 0                                           0.001934
# 1                                           0.015533
# 2                                           0.000187
# 3                                           0.000926
# 4                                           0.000732
#
#    (ILCD 2.0 2018 midpoint, human health, carcinogenic effects)  \
# 0                                       1.142199e-09
# 1                                       1.561707e-09
# 2                                       5.676048e-10
# 3                                       2.191182e-09
# 4                                       1.731384e-09
#
#    (ILCD 2.0 2018 midpoint, human health, ionising radiation)  \
# 0                                           0.001369
# 1                                           0.004844
# 2                                           1.184924
# 3                                           0.009163
# 4                                           0.007240
#
#    (ILCD 2.0 2018 midpoint, human health, non-carcinogenic effects)  \
# 0                                       1.202924e-08
# 1                                       4.135861e-08
# 2                                       3.716515e-09
# 3                                       2.707840e-08
# 4                                       2.139614e-08
#
#    (ILCD 2.0 2018 midpoint, human health, ozone layer depletion)  \
# 0                                       5.099300e-08
# 1                                       6.808792e-09
# 2                                       5.734082e-08
# 3                                       8.781046e-09
# 4                                       6.938799e-09
#
#    (ILCD 2.0 2018 midpoint, human health, photochemical ozone creation)  \
# 0                                           0.000718
# 1                                           0.004120
# 2                                           0.000051
# 3                                           0.000315
# 4                                           0.000249
#
#    (ILCD 2.0 2018 midpoint, human health, respiratory effects, inorganics)  \
# 0                                       1.659245e-09
# 1                                       1.342487e-08
# 2                                       2.871032e-09
# 3                                       4.861033e-09
# 4                                       3.841037e-09
#
#    (ILCD 2.0 2018 midpoint, resources, dissipated water)  \
# 0                                           0.044559
# 1                                           0.077180
# 2                                           0.132819
# 3                                           0.112100
# 4                                           0.088576
#
#    (ILCD 2.0 2018 midpoint, resources, fossils)  \
# 0                                      9.281378
# 1                                     15.350463
# 2                                     14.255169
# 3                                      1.200793
# 4                                      0.948821
#
#    (ILCD 2.0 2018 midpoint, resources, land use)  \
# 0                                       0.170848
# 1                                       2.357585
# 2                                       0.084286
# 3                                       0.592213
# 4                                       0.467936
#
#    (ILCD 2.0 2018 midpoint, resources, minerals and metals)
# 0                                       1.040912e-07
# 1                                       1.142805e-07
# 2                                       5.122173e-08
# 3                                       3.434466e-06
# 4                                       2.713751e-06

# %% [markdown]
# Numbered indices are not very readable. Let's use metadata about the activities as the index instead:

# %%
# get names
names = [a["name"].split(",") for a in lActivities]
df_names = pd.DataFrame(names).fillna(" ")
# split names at the commas to make reading and manipulation easier
col_names = [("name_"+str(c), " ", " ") for c in df_names.columns]
df[col_names] = df_names

# add units and locations
df[("unit"," "," ")] = [a["unit"] for a in lActivities]
df[("location"," "," ")] = [a["location"] for a in lActivities]

# set index
meta_data_cols = col_names + [("unit", " ", " "), ("location", " ", " ")]
df.set_index(meta_data_cols, inplace=True)

df.head()
# Out:
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change biogenic)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000053
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.000162
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000026
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000363
#                                                                                                                                  IN-JH                                                      0.000287
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change fossil)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.588143
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.053454
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.012671
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.077957
#                                                                                                                                  IN-JH                                                      0.061599
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change land use and land use change)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000015
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.000078
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000030
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000177
#                                                                                                                                  IN-JH                                                      0.000140
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change total)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.588211
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.053694
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.012726
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.078496
#                                                                                                                                  IN-JH                                                      0.062025
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater and terrestrial acidification)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000645
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.010851
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000074
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000570
#                                                                                                                                  IN-JH                                                      0.000450
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater ecotoxicity)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.217072
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.074229
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.025228
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.089036
#                                                                                                                                  IN-JH                                                      0.070353
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000008
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.000753
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000009
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000072
#                                                                                                                                  IN-JH                                                      0.000057
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, marine eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000180
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.001528
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000060
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000101
#                                                                                                                                  IN-JH                                                      0.000080
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, terrestrial eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.001934
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.015533
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000187
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000926
#                                                                                                                                  IN-JH                                                      0.000732
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, carcinogenic effects)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  1.142199e-09
#                         hard coal                                                                                  kilowatt hour RoW                                                    1.561707e-09
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                5.676048e-10
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     2.191182e-09
#                                                                                                                                  IN-JH                                                  1.731384e-09
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, ionising radiation)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.001369
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.004844
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.184924
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.009163
#                                                                                                                                  IN-JH                                                      0.007240
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, non-carcinogenic effects)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  1.202924e-08
#                         hard coal                                                                                  kilowatt hour RoW                                                    4.135861e-08
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                3.716515e-09
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     2.707840e-08
#                                                                                                                                  IN-JH                                                  2.139614e-08
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, ozone layer depletion)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  5.099300e-08
#                         hard coal                                                                                  kilowatt hour RoW                                                    6.808792e-09
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                5.734082e-08
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     8.781046e-09
#                                                                                                                                  IN-JH                                                  6.938799e-09
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, photochemical ozone creation)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000718
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.004120
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000051
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.000315
#                                                                                                                                  IN-JH                                                      0.000249
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, respiratory effects, inorganics)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  1.659245e-09
#                         hard coal                                                                                  kilowatt hour RoW                                                    1.342487e-08
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                2.871032e-09
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     4.861033e-09
#                                                                                                                                  IN-JH                                                  3.841037e-09
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, dissipated water)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.044559
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.077180
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.132819
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.112100
#                                                                                                                                  IN-JH                                                      0.088576
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, fossils)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                 9.281378
#                         hard coal                                                                                  kilowatt hour RoW                                                  15.350463
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                              14.255169
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                    1.200793
#                                                                                                                                  IN-JH                                                 0.948821
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, land use)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  0.170848
#                         hard coal                                                                                  kilowatt hour RoW                                                    2.357585
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                0.084286
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     0.592213
#                                                                                                                                  IN-JH                                                  0.467936
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, minerals and metals)
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  1.040912e-07
#                         hard coal                                                                                  kilowatt hour RoW                                                    1.142805e-07
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                5.122173e-08
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     3.434466e-06
#                                                                                                                                  IN-JH                                                  2.713751e-06

# %% [markdown]
# That's it! These are impact scores for all electricity production activities in ecoinvent 3.5. I can use these to answer indicator-specific questions like: Which electricity generation technology has the lowest total global warming potential (GWP 100)?

# %%
df[("ILCD 2.0 2018 midpoint", "climate change", "climate change total")].idxmin()
# Out:
# ('electricity production',
#  ' nuclear',
#  ' boiling water reactor',
#  ' ',
#  ' ',
#  ' ',
#  'kilowatt hour',
#  'US-NPCC')

# %% [markdown]
# Or statistical evaluations, like what is the average and standard deviation for the GWP 100 indicator for all electricity generation activities?

# %%
df[("ILCD 2.0 2018 midpoint", "climate change", "climate change total")].describe()
# Out:
# count    5.000000
# mean     0.359031
# std      0.453299
# min      0.012726
# 25%      0.062025
# 50%      0.078496
# 75%      0.588211
# max      1.053694
# Name: (ILCD 2.0 2018 midpoint, climate change, climate change total), dtype: float64

# %% [markdown]
# ### Sustainability Index

# %% [markdown]
# Using the produced data we can rank the electricity generation datasets according to individual impact indicators. However, a single indicator does not give enough information to decide if a technology is sustainable or not. To get a bigger picture, I want to aggregate all indicators into one number. As mentioned in the introduction, there are infinitely many ways to do this. The one chosen here is not more right or wrong than any other way. Feel free to change this part according to your needs!

# %% [markdown]
# #### Normalization
#
# For each indicator, I choose the minimum and the maximum value over all activities. I define the minimum as 0 and the maximum as 1. Then I use linear interpolation to project all other values into this [0, 1] range.

# %%
df_normalized = df.copy()
for indicator in df.columns:
    max_value = df[indicator].max()
    min_value = df[indicator].min()
    df_normalized[indicator] = (df[indicator] - min_value) / (max_value - min_value)
    
df_normalized.head()
# Out:
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change biogenic)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.079120
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.402550
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         1.000000
#                                                                                                                                  IN-JH                                                      0.773791
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change fossil)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.552922
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.062728
#                                                                                                                                  IN-JH                                                      0.047011
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change land use and land use change)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.388987
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.087117
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         1.000000
#                                                                                                                                  IN-JH                                                      0.770071
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change total)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.552836
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.063182
#                                                                                                                                  IN-JH                                                      0.047359
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater and terrestrial acidification)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.052945
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.045976
#                                                                                                                                  IN-JH                                                      0.034886
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater ecotoxicity)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      1.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.255419
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.332602
#                                                                                                                                  IN-JH                                                      0.235214
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.001290
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.086409
#                                                                                                                                  IN-JH                                                      0.066049
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, marine eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.081488
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.027954
#                                                                                                                                  IN-JH                                                      0.013513
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, terrestrial eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.113848
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.048144
#                                                                                                                                  IN-JH                                                      0.035482
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, carcinogenic effects)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.353906
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.612291
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         1.000000
#                                                                                                                                  IN-JH                                                      0.716799
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, ionising radiation)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.002936
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.006586
#                                                                                                                                  IN-JH                                                      0.004961
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, non-carcinogenic effects)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.220836
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.620632
#                                                                                                                                  IN-JH                                                      0.469677
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, ozone layer depletion)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.874380
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.039030
#                                                                                                                                  IN-JH                                                      0.002573
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, photochemical ozone creation)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.163834
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.064746
#                                                                                                                                  IN-JH                                                      0.048516
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, respiratory effects, inorganics)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.102994
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.272131
#                                                                                                                                  IN-JH                                                      0.185438
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, dissipated water)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.369608
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         0.765254
#                                                                                                                                  IN-JH                                                      0.498725
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, fossils)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                 0.578584
#                         hard coal                                                                                  kilowatt hour RoW                                                   1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                               0.923947
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                    0.017496
#                                                                                                                                  IN-JH                                                 0.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, land use)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  0.038077
#                         hard coal                                                                                  kilowatt hour RoW                                                    1.000000
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                     0.223432
#                                                                                                                                  IN-JH                                                  0.168763
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, minerals and metals)
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.015627
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.018639
#                         nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour LV                                                         1.000000
#                                                                                                                                  IN-JH                                                      0.786975

# %% [markdown]
# The result is a table where all impact scores range between zero and one. Zero means lowest impact with reference to the benchmark (i.e. all ecoinvent 3.5 electricity generation activities). One means highest impact with reference to the benchmark.

# %% [markdown]
# #### Weighing and aggregation

# %% [markdown]
# We still have 19 numbers, each of which describes a small part of the big picture "sustainability". I will now boil them down to one number by simply adding them up. I call the resulting number "sustainability index". Let me stress this again: This index is not more right or wrong than any other one. It is *one* rather arbitrary way to aggregate the individual impact scores.
#
# The lowest possible number for our index is zero. Zero indicates a technology which achieves the *lowest* possible (with reference to the benchmark) impact score in all nineteen impact categories. The highest possible index value is nineteen. It indicates a technology which has the *highest* possible (with reference to the benchmark) impact score in all nineteen impact categories.
#
# Let's see how the ecoinvent activities score in this index:

# %%
# sum
df_normalized[("SUM"," "," ")] = df_normalized.sum(axis=1)

# sort ascending
df_normalized.sort_values(by=("SUM"," "," "), ascending=True, inplace=True)

df_normalized.head()
# Out:
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change biogenic)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.079120
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.773791
#                                                                                                                                  LV                                                         1.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.402550
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change fossil)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.552922
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.047011
#                                                                                                                                  LV                                                         0.062728
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change land use and land use change)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.087117
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.770071
#                                                                                                                                  LV                                                         1.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.388987
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, climate change, climate change total)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.552836
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.047359
#                                                                                                                                  LV                                                         0.063182
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater and terrestrial acidification)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.052945
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.034886
#                                                                                                                                  LV                                                         0.045976
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater ecotoxicity)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      1.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.235214
#                                                                                                                                  LV                                                         0.332602
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.255419
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, freshwater eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.001290
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.066049
#                                                                                                                                  LV                                                         0.086409
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, marine eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.081488
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.013513
#                                                                                                                                  LV                                                         0.027954
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, ecosystem quality, terrestrial eutrophication)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.113848
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.035482
#                                                                                                                                  LV                                                         0.048144
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, carcinogenic effects)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.353906
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.716799
#                                                                                                                                  LV                                                         1.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.612291
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, ionising radiation)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.004961
#                                                                                                                                  LV                                                         0.006586
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.002936
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, non-carcinogenic effects)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.220836
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.469677
#                                                                                                                                  LV                                                         0.620632
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, ozone layer depletion)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.874380
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.002573
#                                                                                                                                  LV                                                         0.039030
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, photochemical ozone creation)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.163834
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.048516
#                                                                                                                                  LV                                                         0.064746
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, human health, respiratory effects, inorganics)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.102994
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.185438
#                                                                                                                                  LV                                                         0.272131
#                         hard coal                                                                                  kilowatt hour RoW                                                        1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, dissipated water)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    1.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.000000
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.498725
#                                                                                                                                  LV                                                         0.765254
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.369608
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, fossils)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                               0.923947
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                 0.578584
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                 0.000000
#                                                                                                                                  LV                                                    0.017496
#                         hard coal                                                                                  kilowatt hour RoW                                                   1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, land use)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                  0.038077
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                  0.168763
#                                                                                                                                  LV                                                     0.223432
#                         hard coal                                                                                  kilowatt hour RoW                                                    1.000000
#
#                                                                                                                                                    (ILCD 2.0 2018 midpoint, resources, minerals and metals)  \
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC                                                    0.000000
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                                                      0.015627
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                                                      0.786975
#                                                                                                                                  LV                                                         1.000000
#                         hard coal                                                                                  kilowatt hour RoW                                                        0.018639
#
#                                                                                                                                                    (SUM,  ,  )
# (name_0,  ,  )         (name_1,  ,  ) (name_2,  ,  )                  (name_3,  ,  ) (name_4,  ,  ) (name_5,  ,  ) (unit,  ,  )  (location,  ,  )
# electricity production  nuclear        boiling water reactor                                                       kilowatt hour US-NPCC              4.115347
#                         natural gas    conventional power plant                                                    kilowatt hour CN-JS                4.678403
#                         photovoltaic   3kWp slanted-roof installation  multi-Si       panel          mounted       kilowatt hour IN-JH                4.905804
#                                                                                                                                  LV                   6.676299
#                         hard coal                                                                                  kilowatt hour RoW                 13.050429

# %% [markdown]
# ### Export
#
# Let's export the absolute and the normalized results to an excel file.

# %%
# transform index into individual columns for easier manipulation
df.reset_index(inplace=True)
df_normalized.reset_index(inplace=True)

# make multi-level headers for better readability
df.columns = pd.MultiIndex.from_tuples(df.columns)
df_normalized.columns = pd.MultiIndex.from_tuples(df_normalized.columns)

# export to xlsx
writer = pd.ExcelWriter("output/ecoinvent_electricity_comparison.xlsx", engine='xlsxwriter')
df.to_excel(writer, sheet_name='abs')
df_normalized.to_excel(writer, sheet_name='norm')
writer.save()

# %% [markdown]
# ### Visualization
#
# Let's draw a heat map showing all normalized impacts for all activities and coloring them according to their magnitude.

# %%
import bokeh.io
import bokeh.models
import bokeh.plotting
from bokeh.palettes import Reds9
import re
import numpy as np

# construct list of activity names for display
names = df.loc[:,meta_data_cols].apply(lambda x: re.sub(' +', ' '," ".join(x[1:])).strip(), axis=1).to_list()

# construct list of method names for display
methods = [", ".join(m[1:]) for m in ilcd]

# define tooltips to be displayed
TOOLTIPS = [
    ("activity", "@act"),
    ("impact category", "@cat"),
    ("normalized score", "@score"),
]

# make figure
f = bokeh.plotting.figure(
    x_axis_label="ILCD 2.0 midpoint indicator", y_axis_label='ecoinvent activity',
    plot_width=900, plot_height=800,   
    tooltips = TOOLTIPS,
    y_range=bokeh.models.FactorRange(*names),
    x_range=bokeh.models.FactorRange(*methods)
)

# define plot data
data = {
    "score": [df_normalized.loc[i,m] for i in df_normalized.index for m in ilcd],
    "act": [names[i] for i in df_normalized.index for m in ilcd],
    "cat": [m for i in df_normalized.index for m in methods],
}

# define colormap
mapper = bokeh.models.LinearColorMapper(palette=Reds9, low=1, high=0)

# plot
f.rect(
    source=data, x="cat", y="act", width=1, height=1,
    fill_color={'field': 'score', 'transform': mapper},
    line_color=None,
)

# rotate x-axis ticks
f.xaxis.major_label_orientation = np.pi / 4
    
# show plot
bokeh.io.output_notebook()
bokeh.io.show(f)
# Out:
#     <div class="bk-root">
#         <a href="https://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="1631">Loading BokehJS ...</span>
#     </div>
#   <div class="bk-root" id="8a597481-c264-464b-9e18-ae3bc871afe8" data-root-id="1594"></div>

# %% [markdown]
# Save the figure to disk.

# %%
bokeh.io.output_file("output/heatmap.html")
path = bokeh.io.save(f)

# %% [markdown]
# ## Discussion
